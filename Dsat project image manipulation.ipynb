# %%
import pandas as pd
import numpy as np
from skimage import io
from skimage import util
import matplotlib.pyplot as plt

# %%
#horizontal flip
def func1():
    temp=np_image[:,::-1]
    plt.imshow(temp)

# %%
#vertical flip
def func2():
    temp=np_image[::-1,:]
    plt.imshow(temp)

# %%
#for inversion
def func3():
    temp=util.invert(np_image)
    plt.imshow(temp)

# %%
#for grayscale
def func4():
    temp=io.imread('img.jpg',as_gray=True)
    plt.imshow(temp)

# %%
print("Welcome to the mini-project")
t=1
while t:
    print("Enter your choices")
    print("1: for image loading \n 2: for editing \n 3 for saving\n 4: for exit")
    choice=int(input("Enter your choice:"))
    if choice == 1:
        np_image=io.imread('img.jpg')
        plt.imshow(np_image)
    elif choice == 2:
        print("How you want to edit\n 1 for hor flip\n 2 for vertical flip \n 3 for invert colors\n 4 for grayscale\n 5 for black ans white\n")
        fin=int(input("Enter your choice:"))
        if fin==1:
            func1()
        elif fin==2:
            func2()
        elif fin==3:
            func3()
        elif fin==4:
            func4()
        else:
            continue
    elif choice == 3:
        print("Image is saved")
    else:
        t=0
# Out:
# Welcome to the mini-project
# Enter your choices
# 1: for image loading
#  2: for editing
#  3 for saving
#  4: for exit
# Enter your choice:1
# Enter your choices
# 1: for image loading
#  2: for editing
#  3 for saving
#  4: for exit
# Enter your choice:2
# How you want to edit
#  1 for hor flip
#  2 for vertical flip
#  3 for invert colors
#  4 for grayscale
#  5 for black ans white
#
# Enter your choice:4
# Enter your choices
# 1: for image loading
#  2: for editing
#  3 for saving
#  4: for exit
# Enter your choice:4
